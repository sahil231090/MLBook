# %% [markdown]
# https://github.com/firmai/financial-machine-learning
# https://github.com/firmai/industry-machine-learning#finance
# https://github.com/wilsonfreitas/awesome-quant
# https://github.com/cbailes/awesome-deep-trading
#
# ML for trading: https://github.com/stefan-jansen/machine-learning-for-trading
# http://cs229.stanford.edu/projects.html
# Idea of the blog: https://quantdare.com/category/artificial-intelligence/
#
#
# Comon template for charts and pictures
# Exciting name of the case studies
#
# For writeup
#
#
# ### Regression:
#
# Many Use cases https://github.com/grananqvist/Awesome-Quant-Machine-Learning-Trading
#
# varMax:http://localhost:8888/notebooks/Book7machine-learning-for-trading-master/08_time_series_models/03_vector_autoregressive_model.ipynb
# https://subscription.packtpub.com/book/big_data_and_business_intelligence/9781784394752/7/ch07lvl1sec41/how-to-develop-a-trading-strategy
# Oil Price:ARIMA and NN
# http://cs229.stanford.edu/proj2017/final-posters/5133462.pdf
#
# Robo advisor: https://towardsdatascience.com/python-for-finance-robo-advisor-edition-36571e0fd48e
#
# Model Calibratipn NN: file:///D:/Download/rtp_hernandez_web%20(1).pdf
# https://open.uct.ac.za/bitstream/handle/11427/29451/thesis_com_2018_haussamer_nicolai_haussamer.pdf?sequence=1&isAllowed=y
#
#
# # Ideas
# Time Series CV : http://localhost:8888/notebooks/Book3/Overall%20Code/packtpub-machine-learning-algo-trading-bots-notebooks/packtpub-notebooks/section%200004/SEC004%20VID002%20Implementing%20GBoosting%20using%20Python.ipynb
#
# https://www.kaggle.com/thebrownviking20/everything-you-can-do-with-a-time-series
# Quandl : http://localhost:8888/notebooks/Book3/section%200001/SEC001%20VID004%20Fetching%20and%20understanding%20the%20Dataset.ipynb
#
# Performance:http://localhost:8888/notebooks/Book3/section%200002/SEC002%20VID004%20Evaluate%20Random%20Forests%20Performance.ipynb
# https://www.kaggle.com/mczielinski/bitcoin-historical-data/kernels
#
#
# ### Pricing - Deep Hedging
# https://github.com/mgroncki/DataScienceNotebooks/blob/master/DeepHedging/DeepHedging_Part1.ipynb
# Pricing: https://github.com/mgroncki/DataScienceNotebooks/blob/master/ExoticsDerviatePricingWithTensorFlow/BermudanTensorFlow.ipynb
#
# ### Chapter 3
#
# NN and Keras JupyterNotebook : Chapter 3
# http://localhost:8888/notebooks/Book1-MLinFinance/1%20A%20neural%20network%20from%20scratch%20%26%20Intro%20to%20Keras.ipynb
#
# ### CHapter :LSTM
# http://localhost:8888/notebooks/Book1-MLinFinance/5.2%20Classifying%20Tweets.ipynb
#
# ### Clustering :
# https://quant.stackexchange.com/questions/24696/which-are-useful-applications-of-clustering-in-quantitative-finance
#
# Theory:
# https://subscription.packtpub.com/book/big_data_and_business_intelligence/9781787125933/11
# https://towardsdatascience.com/unsupervised-learning-for-anomaly-detection-in-stock-options-pricing-e599728958c7
#
# Trading Strategy:
# https://github.com/marketneutral/pairs-trading-with-ML/blob/master/Pairs%2BTrading%2Bwith%2BMachine%2BLearning.ipynb
#
# Others:
#
#
# http://cs229.stanford.edu/proj2017/final-posters/csoo.pdf
#
# Industry/Fund clustering:
# https://github.com/SeanMcOwen/FinanceAndPython.com-ClusteringIndustries
# https://github.com/frechfrechfrech/Mutual-Fund-Market-Clusters/blob/master/Initial%20Data%20Exploration.ipynb
# https://github.com/firmai/financial-machine-learning refer unsupervised
#
# Portfolio Management- My own project with the clusters explained.
# http://cs229.stanford.edu/proj2017/final-posters/5135626.pdf
#
#
# #### PCA:
#
# http://www.turingfinance.com/artificial-intelligence-and-statistics-principal-component-analysis-and-self-organizing-maps/
#
# Theory: https://subscription.packtpub.com/book/big_data_and_business_intelligence/9781787125933/5
#
# https://www.analyticsvidhya.com/blog/2018/08/dimensionality-reduction-techniques-python/
#
# https://towardsdatascience.com/dimension-reduction-techniques-with-python-f36ca7009e5c
#
#
# Factor Model:
# https://github.com/WenkaiCUi/PCA-and-Factor-Model/blob/master/Principle%20Component%20Analysis%20in%20Finance.ipynb
#
# Trading Strategy :
# https://www.linkedin.com/pulse/how-principal-component-analysis-can-improve-longshort-charles-ellis/
# https://github.com/evrial/PCA-dimensionality-reduction
# https://github.com/joelQF/quant-finance/blob/master/Artificial_IntelIigence_for_Trading/pca_factor_model.ipynb
# file:///D:/Download/Intraday_trading_rules_based_on_Self_Org.pdf
#
# https://github.com/marketneutral/pairs-trading-with-ML/blob/master/Pairs%2BTrading%2Bwith%2BMachine%2BLearning.ipynb
#
#
# === Case Study 3: Porfolio Management
# https://github.com/Gustrigos/Eigen-Portfolio/blob/master/ml.ipynb
# https://colab.research.google.com/drive/1mm9r6EZOERHYkycDbc74GY7S2U6h1oTc
# http://localhost:8888/notebooks/Book11-Hands-On-Machine-Learning-for-Algorithmic-Trading/Chapter12/01_linear_dimensionality_reduction/03_pca_and_risk_factor_models.ipynb
#
# === Case Study 4: Yield Curve Construction:
# https://clinthoward.github.io/portfolio/2017/08/19/Rates-Simulations/
# http://www.bondeconomics.com/2018/12/principal-component-analysis-and-hedge.html
# https://github.com/linanqiu/pca-irs-stat-project/blob/master/Principal%20Component%20Analysis%20on%20Interest%20Rate%20Swaps.ipynb
#
# Bonus Index Construction:
# This article explores the use of a variational autoencoder to reduce the dimensions of financial time series with Keras and Python.
# Deep Learning
# https://towardsdatascience.com/variational-autoencoder-in-finance-53ee5eb9ed98
#
# t-SNE : Data Visualization
#
# https://quantdare.com/tsne/
#
#
#
# ### Reinforcement Learning:
# https://github.com/stefan-jansen/machine-learning-for-trading/blob/master/20_reinforcement_learning/04_q_learning_for_trading.ipynb
#
# Trading Strategy
#
# https://github.com/borisbanushev/stockpredictionai/blob/master/readme2.md#reinforcementlearning_further
# https://www.ai-articles.net/deep-q-learning-test-results-for-algorithmic-trading/
#
#
#
# Portfolio Management:
# http://cs229.stanford.edu/proj2016/report/JinElSaawy-PortfolioManagementusingReinforcementLearning-report.pdf
# http://cs229.stanford.edu/proj2016/poster/El-SaawyJin-PortfolioManagementUsingReinforcementLearning.pdf
# https://github.com/selimamrouni/Deep-Portfolio-Management-Reinforcement-Learning
#
#
# ### NLP
#
# sentiments analysis
# http://localhost:8888/notebooks/Book7machine-learning-for-trading-master/13_working_with_text_data/05_sentiment_analysis_twitter.ipynb
# https://towardsdatascience.com/a-new-way-to-sentiment-tag-financial-news-9ac7681836a7
# https://towardsdatascience.com/https-towardsdatascience-com-algorithmic-trading-using-sentiment-analysis-on-news-articles-83db77966704
# http://cs229.stanford.edu/proj2019spr/poster/27.pdf
# http://cs229.stanford.edu/proj2018/report/82.pdf
# Chatbot:
# http://localhost:8888/notebooks/Book5-Chatbots/6201_Section%206_Build%20a%20Chatbot.ipynb
# http://cs229.stanford.edu/proj2018/poster/72.pdf
#
# Documentation automation:
# https://github.com/healthgradient/sec-doc-info-extraction/blob/master/classify_sections_containing_relevant_information.ipynb
# https://towardsdatascience.com/sentiment-analysis-of-economic-reports-using-logistic-regression-9f04891c338
#
# http://cs229.stanford.edu/proj2016/poster/ZhangWanLiu-UnstructuredDocumentRecognitiononBusinessInvoice-poster.pdf
#
# ## CHeatsheet for writeup:
# https://github.com/abhat222/Data-Science--Cheat-Sheet
# https://medium.com/datadriveninvestor/classification-algorithms-in-machine-learning-85c0ab65ff4
# https://towardsdatascience.com/financial-storytelling-using-time-series-classification-185094f80db5
# https://github.com/rasbt/pattern_classification/blob/master/resources/data_glossary.md

# %%
Robo Advisor : Each component- Leverage other modules
    Optimisation http://www.thierry-roncalli.com/download/SwissQuant-Conference-Robo-Roncalli-2019.pdf
    Allocation : https://blog.alpaca.markets/blog/2018/6/8/i-am-a-college-student-and-i-built-my-own-roboadvisor
    NN : https://ieeexplore.ieee.org/document/8710559
    AI: Like Betterment, he company claims that its AI engine automatically allocates assets and determines which investments will result in minimum taxes.
    Forecast: SigFig is a robo-advisor that offers customers investment recommendations, analysis, and tracking from a mobile application or web browser. According to this review of the application, the machine learning methodology uses historical market data to simulate scenarios, make projections, and determine how the user’s investment could potentially perform.
https://github.com/prof-rossetti/robo-advisor-demo-2019
    https://kdboller.github.io/2019/04/06/python-for-finance-robo-advisor-edition.html
    https://github.com/kdboller/pythonsp500-robo-advisor-edition/blob/master/Robo%20Advisor%20Strategy%20notebook_v1.ipynb
        AI—Can you make sense of the economy, the markets & help optimize my portfolio?
        
https://www.datadriveninvestor.com/2019/02/08/machine-learning-in-finance/
https://github.com/as6140/peervest
        
=== Why a book on Machine Learning in Finance



****
* Gap between ideas and implementation in Finance - the book aims to bridge the gap.
* Misconception that big data is needed for implementing machine learning models
* Misconception about the skill required for implementing machine learning models - overstated
* Implementing machine learning models is more data analysis and less data science

<Table with the pros and cons of each algorithm>
Chart with the trend

****

# %% [markdown]
# ### Classification:
# One Hot Encoding :
# Trend Predictor:
# https://github.com/sasankauppu3/AI-Stock-market-trend-predictor/blob/master/Predictor.py
# Lending Club Loan Default:
# https://github.com/jgcorliss/lending-club/blob/master/predicting_chargeoff.ipynb
# https://github.com/yanxiali/Predicting-Default-Clients-of-Lending-Club-Loans/blob/master/results/LC_Loan_full.md
# https://www.kaggle.com/przemekblo/lending-club-loan-classification
#
# Classification Forecast IP Market : http://localhost:8888/notebooks/Book5-Chatbots/6201_Section%202_%20Forecast%20the%20IPO%20Market%20using%20Logistic%20Regression.ipynb
#
# MArket Microstructure :http://localhost:8888/notebooks/Book5-Chatbots/6201_Section%204_Forecast%20the%20Stock%20Market%20with%20Machine%20Learning.ipynb
#
# Keras: https://www.kaggle.com/marklam/a-neutral-network-to-read-btc-price-action
# Details of a tree: http://localhost:8888/notebooks/Book1-MLinFinance/2%20structured%20data.ipynb
#
# #Fraud Detection :https://www.kaggle.com/arjunjoshua/predicting-fraud-in-financial-payment-services/
# Bank Failures: https://github.com/Ahmed0028/Machine-Learning-and-Reinforcement-Learning-in-Finance-Specialization/blob/master/Bank_failure_m1_ex4_v3.ipynb
# https://github.com/joelowj/Machine-Learning-and-Reinforcement-Learning-in-Finance/blob/master/Bank_failure_rand_forests_m2_ex1.ipynb
#
# Bond Liquidity Prediction :https://github.com/ishank011/gs-quantify-bond-prediction/blob/master/bonds.ipynb
#
# https://github.com/firmai/industry-machine-learning#finance
# Trading Strategy : https://github.com/DIVAKAR92/HSBC_Hackathon
# https://www.kaggle.com/zhunqiang/bank-loan-default-prediction
# https://www.kaggle.com/fedecape/predict-btc-price-movement
# https://www.kaggle.com/teresahornsby/logistic-regression-for-cryptocurrencies
# Best: https://github.com/perfectyayra/Algo-Trading-Project/blob/master/Project/Algorithms%20Trading%20Final%20Project%20Part%203.ipynb
#
# Global Stock Selection Strategy:
# https://github.com/anthonyng2/Machine-Learning-For-Finance/blob/master/Classification%20Based%20Machine%20Learning%20for%20Algorithmic%20Trading/Global_Stock_Selection_14_Fundamental_factors%2B-%2BLogistic%2Bgit.ipynb
# Prices will go up or down based on order book etc: http://cs229.stanford.edu/proj2019/poster/28.pdf
#
# https://github.com/t-cousins/Kaggle-Algorithmic-Trading-Challenge/blob/master/Algorithmic_Trading_Challenge.ipynb
#
# http://cs229.stanford.edu/proj2018/poster/76.pdf
# http://cs229.stanford.edu/proj2017/final-posters/5148376.pdf
#
# #People change their risk tolerance based on Market Situation - My project
#
# Exercise : Bank Default : Extension of the fraud detection
# Next minute : Price will go up or down: Take tick level data
# Insurance Claims : Whether insurance will be claimed or not: Charge off- Out of 57 what to select
